# %% [markdown]
# # This is exploratory data analysis of data generated by APSCHE-British Council programme. Data involves pre-assessment tests(OPT) and final-assessment(APTIS) tests.

# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
import re

# %% [markdown]
# OPT stands for Online Placement Test, which is a pre-assessment test taken to understand the learning levels of students beore imparting the training. It has following important characteristics -
# 1. It is a 40 min test
# 2. At the end of the test each student received CEFR (Common European Framework) grade between
#     - <b>A0 (Beginner)
#     - A1 (Elementary)
#     - A2 (Pre-Intermediate)
#     - B1-B2 (Intermediate)</b>

# %%
#OPT Data.
# It has students details, their college name (in HomeDomain column), Status (Completed or Incomplete), Date enrolled
# Completed Date and CEFR level 
opt_report = pd.read_csv('opt_report.csv')
opt_report = opt_report.rename(columns = {'AP NT CEFR level':'CEFR_grade'})
print(opt_report.head())
print(opt_report.columns)
# Out:
#      First_Name   Last_Name                             Email  \
# 0  naga pradeep       kathi           pradeepcaty72@gmail.com
# 1  manchikanti      meghana  meghana.manchikanti123@gmail.com
# 2       PANDETI        RAJU        yashwanthpandeti@gmail.com
# 3      Ramadevi   Vennapusa      ramagopalvennapusa@gmail.com
# 4           NaN         NaN                               NaN
#
#                                           HomeDomain      Status  \
# 0        SV College Engineering (Tirupati, Chittoor)   Completed
# 1   Santhiram Engineering College (Nandyal, Kurnool)   Completed
# 2  Siddharth Institute Science Technology (Puttur...   Completed
# 3  N.B.K.R. Institute of Science and Technology (...   Completed
# 4  Sree Venkateswara College of Engineering (Koda...  Incomplete
#
#   Date_Enrolled Completed_Date CEFR_grade
# 0    09/10/2017     11/10/2017         B1
# 1    18/08/2017     22/08/2017         B1
# 2    14/08/2017     06/09/2017         B1
# 3    17/08/2017     01/09/2017         B1
# 4    04/09/2017            NaN        NaN
# Index(['First_Name', 'Last_Name', 'Email', 'HomeDomain', 'Status',
#        'Date_Enrolled', 'Completed_Date', 'CEFR_grade'],
#       dtype='object')

# %% [markdown]
# <B>How many students successfully completed OPT exam?</B>

# %%
opt_report_completed = opt_report[opt_report['Status'] == 'Completed']
# There are still some rows with status as Completed but CEFR grade is NaN. We will remove those rows altogether
# as students don't have grades.
opt_report_completed = opt_report_completed.dropna()
opt_report_completed.shape
# Out:
# (31599, 8)

# %% [markdown]
# <b>31599 students overall completed OPT test</b>

# %% [markdown]
# <b>Distribution of OPT scores? </b>

# %%
total_students = sum(opt_report_completed['CEFR_grade'].value_counts())
opt_bar_plot = opt_report_completed['CEFR_grade'].value_counts().plot(kind='bar', fontsize = 14, figsize = (5,5))
opt_bar_plot.set_xlabel('CEFR grades', fontsize = 18)
opt_bar_plot.set_ylabel('Number of students', fontsize = 18)
opt_bar_plot.set_title('OPT Score Bar Chart', fontsize = 18)
for i in opt_bar_plot.patches:
    opt_bar_plot.text(i.get_x() - 0.03, i.get_height() + 5.0, str(round((i.get_height()/total_students)*100, 2))+'%', fontsize = 14, color = 'black')

# %% [markdown]
# <h3> OPT scores analysis</h3>
# <h4>As visible more than 44% of the students scored B1 which is intermediate score and more than 41% of the students scored A2 which is pre-intermediate score.
# Generalising for all enrolled students, we can safely assume that more than 80% of our population was in A2 & B1 (CEFR grades)range before and after the training. </h4>

# %% [markdown]
# <h2>APTIS(post training assessment test) scores Analysis</h2>
#
# APTIS is a 40 min exam consisting of 2 sections
#  - Grammar & Vocabulary
#  - Speaking

# %%
aptis_report = pd.read_csv('aptis_report.csv')
#We are only concerned with APTIS grades at this point and not with Raw Scores (Reduces complexity as well).
aptis_report.drop(['Raw Score', 'Test Name'], axis=1, inplace=True)
aptis_report = aptis_report.dropna()
aptis_report_final = aptis_report

# %% [markdown]
# <h3>As visible above, following columns are available in processed APTIS scores dataframe</h3>
#  - Full Name of the students
#  - Test Centre which is same as the college
#  - Raw Score - (This is the total score obtained in both the sections)
#  - CEFR Grade (This is the final grade of the student)

# %% [markdown]
# <B>How many students successfully completed APTIS exam (as of January 20th 2019)?</B>

# %%
aptis_report_final.shape
# Out:
# (21409, 4)

# %% [markdown]
# <b>21409 students overall have completed APTIS test till now</b>

# %% [markdown]
# <b>Distribution of APTIS scores? </b>

# %%
total_students_aptis = sum(aptis_report_final['CEFR Grade'].value_counts())
aptis_bar_plot = aptis_report_final['CEFR Grade'].value_counts().plot(kind='bar', fontsize = 14, figsize = (5,5))
aptis_bar_plot.set_xlabel('CEFR grades', fontsize = 18)
aptis_bar_plot.set_ylabel('Number of students', fontsize = 18)
aptis_bar_plot.set_title('APTIS Grade Bar Chart', fontsize = 18)
for i in aptis_bar_plot.patches:
    aptis_bar_plot.text(i.get_x() - 0.03, i.get_height() + 5.0, str(round((i.get_height()/total_students_aptis)*100, 2))+'%', fontsize = 14, color = 'black')

# %% [markdown]
# <h3>More than 46% of 22000 students have scored B1 grade. Furthermore, remaining 50%+ is almost equally divided in A0, B2, A2 respectively</h3>

# %% [markdown]
# <h3>Comparative analysis of bar charts of OPT and APTIS</h3>

# %%
#<TODO:>Reptition of code to generate OPT and APTIS graph side by side for time being till I find a fix to show both graphs side by side.

fig, axs = plt.subplots(1,2)    
total_students_aptis = sum(aptis_report_final['CEFR Grade'].value_counts())
aptis_bar_plot = aptis_report_final['CEFR Grade'].value_counts().plot(kind='bar', fontsize = 14, figsize = (10,5), ax=axs[0])
aptis_bar_plot.set_xlabel('CEFR grades', fontsize = 18)
aptis_bar_plot.set_ylabel('Number of students', fontsize = 18)
aptis_bar_plot.set_title('APTIS Grade Bar Chart', fontsize = 18)
for i in aptis_bar_plot.patches:
    aptis_bar_plot.text(i.get_x() - 0.03, i.get_height() + 5.0, str(round((i.get_height()/total_students_aptis)*100, 2))+'%', fontsize = 14, color = 'black')

    
#<TODO:>Reptition of code to generate OPT graph here for time being till I find a fix to show both graphs side by side.
total_students_opt = sum(opt_report_completed['CEFR_grade'].value_counts())
opt_bar_plot = opt_report_completed['CEFR_grade'].value_counts().plot(kind='bar', fontsize = 14, figsize = (10,5), ax=axs[1])
opt_bar_plot.set_xlabel('CEFR grades', fontsize = 18)
opt_bar_plot.set_ylabel('Number of students', fontsize = 18)
opt_bar_plot.set_title('OPT Score Bar Chart', fontsize = 18)
for i in opt_bar_plot.patches:
    opt_bar_plot.text(i.get_x() - 0.03, i.get_height() + 5.0, str(round((i.get_height()/total_students_opt)*100, 2))+'%', fontsize = 14, color = 'black')

# %% [markdown]
# <h3>As we juxtapose the bar graphs of OPT (Pre-assessment test) and APTIS (Final test) side by side, we come to following conclusion</h3>
# - Almost half of the population still remains in B1 grade.
# - IN OPT (Pre-assessment test) the other half (almost) had majorly A2 grade. However, in APTIS (Final test) other half is almost equally divided into A0,B2,A2-
#   - A0 (This is a lower grade than A2. This could be explained as some of the students who were not part of OPT pre-assesment test or training were allowed to given test)
#   - A2 (This is the same grade as A2. This population has either not benefitted from training or like above, they also were not part of OPT and training)
#   - B2 (This populations shows much improvement with grade improvement from A2 to B2)
#
# <b>Note: There is almost 10% increase in number of C grades (highest grade) from 0.06% to 0.65%</b>

# %% [markdown]
# <h2>Removing Noise from Signal</h2>

# %% [markdown]
# <h2>Following are the thirteen colleges which had completed OPT, had shown strong interest in training and have complete the APTIS. We should analyse the OPT and APTIS bar graphs for only these colleges also to get better idea of the effect of training on students where program was conducted in the best possible way.</h2>
# 1. SV College Engineering (Tirupati, Chittoor)
# 2. Andhra Loyola Institute of Engineering and Technology (Vijayawada, Krishna)
# 3. Sree Vidyanikethan Engineering College (Tirupati, Chittoor)
# 4. S.R.K.R.Engineering College (Bhimavaram, West Godavari)
# 5. Ramachandra College of Engineering (Eluru, West Godavari)
# 6. Swarnandhra College of Engineering and Technology (Narasapur, West Godavari)
# 7. Dhanekula Institute of Engineering andTechnology (Vijayawada, Krishna)
# 8. Bapatla Engineering College (Bapatla, Guntur)
# 9. Bapatla Women’s Engineering College (Bapatla, Guntur)
# 10. DVR and Dr HS MIC College Of Technology (Kanchikacherla, Krishna)
# 11. Sri Padmavati Mahila Visvavidyalayam (Tirupati, Chittoor)
# 12. Pragati Engiineering College (Surampalem, East Godavari)
# 13. RVR and JC College of Engineering (Chowdavaram, Guntur)

# %%
best_colleges = ['SV College of Engineering', 'Andhra Loyola Institute of Engineering and Technology', 'Sree Vidyanikethan Engineering College',\
                'S.R.K.R. Engineering College', 'Swarnandhra College of Engineering and Technology', 'Ramachandra College of Engineering', \
                'Dhanekula Institute of Engineering and Technology',\
                'Bapatla Engineering College', 'Bapatla Womens Engineering College', 'DVR and Dr HS MIC College Of Technology', 'Sri Padmavati Mahila Visvavidyalayam',\
                'Pragati Engiineering College', 'RVR and JC College of Engineering']
best_colleges = [x.replace('.','').strip().lower() for x in best_colleges]
best_colleges
# Out:
# ['sv college of engineering',
#  'andhra loyola institute of engineering and technology',
#  'sree vidyanikethan engineering college',
#  'srkr engineering college',
#  'swarnandhra college of engineering and technology',
#  'ramachandra college of engineering',
#  'dhanekula institute of engineering and technology',
#  'bapatla engineering college',
#  'bapatla womens engineering college',
#  'dvr and dr hs mic college of technology',
#  'sri padmavati mahila visvavidyalayam',
#  'pragati engiineering college',
#  'rvr and jc college of engineering']

# %%
#OPT data for 13 colleges.
opt_best_colleges = opt_report_completed
opt_best_colleges['HomeDomain'].replace(to_replace=r'\(.+\)', value='',inplace=True,regex=True)
opt_best_colleges['HomeDomain'] = opt_best_colleges['HomeDomain'].apply(lambda x: x.replace('.','').strip().lower())
#Bug fix (missing space) for SRKR engineering college.
#opt_best_colleges[opt_best_colleges['HomeDomain'] == 'srkrengineering college'] = 
opt_best_colleges['HomeDomain'].replace('srkrengineering college', 'srkr engineering college', inplace=True)
opt_best_colleges = opt_best_colleges[opt_best_colleges['HomeDomain'].isin(best_colleges)]
opt_best_colleges.shape
#Tests Start
#print(opt_best_colleges[opt_best_colleges['HomeDomain'] == 'srkr engineering college'])
#print(opt_best_colleges[opt_best_colleges['HomeDomain'] == 'dvr and dr hs mic college of technology'])
#print(opt_best_colleges[opt_best_colleges['HomeDomain'] == 'rvr and jc college of engineering'])
#Tests End
# Out:
# (5968, 8)

# %%
#<TODO>
#APTIS data for 13 colleges.
aptis_best_colleges = aptis_report_final
#aptis_best_colleges['College'] = aptis_best_colleges['College'].apply(lambda x: x.replace('.','').strip().lower())
aptis_best_colleges
#aptis_best_colleges = aptis_best_colleges[aptis_best_colleges['College'].isin(best_colleges)]
#Tests Start
#print(opt_best_colleges[opt_best_colleges['College'] == 'srkr engineering college'])
#print(opt_best_colleges[opt_best_colleges['HomeDomain'] == 'dvr and dr hs mic college of technology'])
#print(opt_best_colleges[opt_best_colleges['HomeDomain'] == 'rvr and jc college of engineering'])
#Tests End
# Out:
#        index                                  Full Name  \
# 0          0                                   A AKHILA
# 1          1                                  A ALEKHYA
# 2          2                       A B N SRI GURU DATTA
# 3          3                                   A BALAJI
# 4          4                                 A BHARGAVA
# 5          5                           A HARSHA VARDHAN
# 6          6                                  A KISHORE
# 7          7                              A LOKESH NULL
# 8          8                                  A MADHURI
# 9          9                          A MD MALIKA BEGUM
# 10        10                              A MEENA AVULA
# 11        11                           A NAVEEN CHANDRA
# 12        12                                  A PRAVEEN
# 13        13                A R Vamsi Krishna Garimella
# 14        14                      A RAJARAJESHWARI ATLA
# 15        15                                 A RISHITHA
# 16        16                             A ROHITH KUMAR
# 17        17                       A S PRAJWAL HIREMATH
# 18        18                  A S S MOUNIKA KHANDAVILLI
# 19        19                            A SAISURYA NULL
# 20        20                A SATYA KRISHNA KUNAPAREDDY
# 21        21                            A SIREESHA NULL
# 22        22                               A SIVA KUMAR
# 23        23                         A SIVA KUMAR YADAV
# 24        24                     A SREEMANTH REDDY NULL
# 25        25                          A SURYA TEJA NULL
# 26        26     A VEERA VENKATA RAMANJALI DEVI ADABALA
# 27        27                          A VENKATA KRISHNA
# 28        28                              A VIJAY KUMAR
# 29        29                           AADAPA CHANDRIKA
# ...      ...                                        ...
# 21970  21970                   YUVA DURGA PRAVEEN GANDI
# 21971  21971                        YUVA KISHORE GUDALA
# 21972  21972                             YUVA SURYA S D
# 21973  21973                         YUVA TEJA GILLELLA
# 21974  21974                          YUVALAKSHMI AKKEM
# 21975  21975                        YUVAMANJUNATH REDDY
# 21976  21976                          YUVARAJ VARATHURU
# 21977  21977                          YUVARAJU MUDUNURI
# 21978  21978                           Yaddala Gayathri
# 21979  21979                      Yamini Krishna Atkuri
# 21980  21980                        Yandakuditi Mounika
# 21981  21981                  Yandra Ganga Krishna Veni
# 21982  21982                            Yelusuru Rakesh
# 21983  21983                               ZAHEER AHMED
# 21984  21984                         ZAHEERABBAS GALETI
# 21985  21985                                ZAHID SHAIK
# 21986  21986                       ZAHIDHUSSAIN BAJKHOR
# 21987  21987              ZEDDA RIKHIL JOSEPH NOT FOUND
# 21988  21988                                akmal shaik
# 21989  21989                       kolasani sree swathi
# 21990  21990                         kopuri Kiran kumar
# 21991  21991                    kumari chandrika varada
# 21992  21992                              mary penumala
# 21993  21993                              pasam meghana
# 21994  21994  pavan sri surya hemanth Kumar telagareddi
# 21995  21995                                sai maddula
# 21996  21996                               tulasi kante
# 21997  21997                        vakkalanka Abhilash
# 21998  21998                               vamsi gurram
# 21999  21999                        vineetha tatiparthi
#
#                                              Test Centre  Raw Score  \
# 0      Gouthami Institute of Technology and Managemen...         33
# 1        Sree Vidyanikethan Engineering College reupload         65
# 2                  JNTUA College of Engineering Chittoor         52
# 3          Siddharth Institute of Science and Technology         23
# 4      Rajeev Gandhi Memorial College of Engineering ...         26
# 5      Annamacharya Institute of Technology and Sciences         33
# 6                                   Dravidian University         28
# 7      Rajeev Gandhi Memorial College of Engineering ...         56
# 8      Rajeev Gandhi Memorial College of Engineering ...         66
# 9             Bheema Institute of Technology and Science         60
# 10     Raghavendra Institute Pharmaceutical Education...         46
# 11     Rajeev Gandhi Memorial College of Engineering ...         27
# 12         Siddharth Institute of Science and Technology         23
# 13                           Pragati Engineering College         54
# 14     Raghavendra Institute Pharmaceutical Education...         39
# 15                            Andhra Engineering College         28
# 16                            Andhra Engineering College         51
# 17                JNTUA College of Engineering Anantapur        108
# 18                           Pragati Engineering College         60
# 19       Sree Vidyanikethan Engineering College reupload         63
# 20        Swarnandhra College of Engineering  Technology         26
# 21       Sree Vidyanikethan Engineering College reupload         34
# 22     Annamacharya Institute of Technology and Sciences         36
# 23     Annamacharya Institute of Technology and Sciences         37
# 24                           KSRM College of Engineering         22
# 25       Sree Vidyanikethan Engineering College reupload         60
# 26             Shri Vishnu Engineering college for Women         46
# 27         ANU ANU College of Engineering and Technology         36
# 28     Rajiv Gandhi University of Knowledge Technologies         49
# 29                    Ramachandra college of engineering         20
# ...                                                  ...        ...
# 21970     Swarnandhra College of Engineering  Technology         49
# 21971     Swarnandhra College of Engineering  Technology         33
# 21972           NBKR Institute of Science and Technology         59
# 21973    Sree Vidyanikethan Engineering College reupload         40
# 21974     Sri Venkateswara Engineering College for Women         36
# 21975    Madanapalle Institute of Technology and Science         28
# 21976                          SV College of Engineering         43
# 21977  Dhanekula Institute of Engineering and Technology         12
# 21978              JNTUA College of Engineering Chittoor         80
# 21979                   Gudlavalleru Engineering College         33
# 21980                        Pragati Engineering College         58
# 21981                        Pragati Engineering College         49
# 21982                        Pragati Engineering College         30
# 21983  Annamacharya Institute of Technology and Sciences         32
# 21984    Sree Vidyanikethan Engineering College reupload         45
# 21985  Annamacharya Institute of Technology and Sciences         39
# 21986    Sree Vidyanikethan Engineering College reupload         48
# 21987             JNTUA College of Engineering Anantapur         59
# 21988                   Gudlavalleru Engineering College         13
# 21989                   Gudlavalleru Engineering College         54
# 21990                   Gudlavalleru Engineering College         30
# 21991     Swarnandhra College of Engineering  Technology         43
# 21992                   Gudlavalleru Engineering College         25
# 21993                   Gudlavalleru Engineering College         10
# 21994                   Gudlavalleru Engineering College         16
# 21995                   Gudlavalleru Engineering College         27
# 21996            DVR and Dr HS MIC College Of Technology         21
# 21997                        Pragati Engineering College         50
# 21998            DVR and Dr HS MIC College Of Technology         38
# 21999            DVR and Dr HS MIC College Of Technology         11
#
#       CEFR Grade                                            College
# 0             A1         Bheema Institute of Technology and Science
# 1             A1    Sree Vidyanikethan Engineering College reupload
# 2             B1     Sri Venkateswara Engineering College for Women
# 3             B2                     Dr Lankapalli Bullayya College
# 4             A2      Siddharth Institute of Science and Technology
# 5             A0    Madanapalle Institute of Technology and Science
# 6             B1  Sri Venkatesa Perumal College of Engineering a...
# 7             B1                          SV College of Engineering
# 8             B1  Sri Venkateswara College of Engineering and Te...
# 9             B1    Sree Vidyanikethan Engineering College reupload
# 10            B1  Rajiv Gandhi University of Knowledge Technologies
# 11            B1     Sri Venkateswara Engineering College for Women
# 12            B1                          SV College of Engineering
# 13            B1           NBKR Institute of Science and Technology
# 14            B1    Sree Vidyanikethan Engineering College reupload
# 15            B1  Potti Sriramulu Chalavadi Mallikarjuna Rao Col...
# 16            B1        Srinivasa Ramanujan Institute of Technology
# 17            B1  Sri Venkatesa Perumal College of Engineering a...
# 18            B1     Sri Venkateswara Engineering College for Women
# 19            B1       Aditya College of Engineering and Technology
# 20            B1     Sri Venkateswara Engineering College for Women
# 21            B1    Sree Vidyanikethan Engineering College reupload
# 22            B2                           SRKR Engineering College
# 23            B1     Malineni Lakshmaiah Womens Engineering College
# 24            B1                   Dhanekula College of Engineering
# 25            A2   Swarnandhra Institute of Engineering  Technology
# 26            B2                     Dr Lankapalli Bullayya College
# 27            B2                        KSRM College of Engineering
# 28            A2             JNTUA College of Engineering Anantapur
# 29            B1           NBKR Institute of Science and Technology
# ...          ...                                                ...
# 21970        NaN                                                NaN
# 21971        NaN                                                NaN
# 21972        NaN                                                NaN
# 21973        NaN                                                NaN
# 21974        NaN                                                NaN
# 21975        NaN                                                NaN
# 21976        NaN                                                NaN
# 21977        NaN                                                NaN
# 21978        NaN                                                NaN
# 21979        NaN                                                NaN
# 21980        NaN                                                NaN
# 21981        NaN                                                NaN
# 21982        NaN                                                NaN
# 21983        NaN                                                NaN
# 21984        NaN                                                NaN
# 21985        NaN                                                NaN
# 21986        NaN                                                NaN
# 21987        NaN                                                NaN
# 21988        NaN                                                NaN
# 21989        NaN                                                NaN
# 21990        NaN                                                NaN
# 21991        NaN                                                NaN
# 21992        NaN                                                NaN
# 21993        NaN                                                NaN
# 21994        NaN                                                NaN
# 21995        NaN                                                NaN
# 21996        NaN                                                NaN
# 21997        NaN                                                NaN
# 21998        NaN                                                NaN
# 21999        NaN                                                NaN
#
# [22000 rows x 6 columns]
